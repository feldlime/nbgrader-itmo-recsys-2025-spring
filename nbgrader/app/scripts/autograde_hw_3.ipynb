# %%
import os
os.chdir("/app")

# %%
import pandas as pd
from pathlib import Path
from nbgrader.api import Gradebook
from nbgrader.apps import NbGraderAPI
from traitlets.config import Config
from tqdm.auto import tqdm
import re
import os
import time

# %%
COURSE_ID = "itmo_recsys_2025_spring"

# %%
config = Config()
config.CourseDirectory.course_id = COURSE_ID
# config.ExecutePreprocessor.environment = {
#     'DATA_PATH_2': '/path/to/data'
# }
config.ExecutePreprocessor.timeout = 1800

# %%
nbg = NbGraderAPI(config=config)
gradebook = nbg.gradebook

# %%
ASSIGNMENT = "hw_3"
NOTEBOOK = "knn"  # without .ipynb
MAX_SCORE = 15

# %%
os.environ["DATA_PATH"] = "/usr/local/share/nbgrader/exchange/data/data_original"

# %%
1MaxOn1
AlViKl
Kraagger-del
limmark21
nbelyaev1
nikiduki

# %%
student_ids = {s["id"] for s in nbg.get_students()}
sorted(student_ids - nbg.get_autograded_students(ASSIGNMENT))
# Out:
# ['1MaxOn1',
#  'AlViKl',
#  'Kraagger-del',
#  'ONEPANTSU',
#  'limmark21',
#  'nbelyaev1',
#  'nikiduki']

# %%
sorted(student_ids - nbg.get_submitted_students(ASSIGNMENT))
# Out:
# ['1MaxOn1', 'AlViKl', 'Kraagger-del', 'limmark21', 'nbelyaev1', 'nikiduki']

# %%
nbg.get_students()
# Out:
# [{'id': 'koshkidadanet',
#   'first_name': 'Денис Вадимович',
#   'last_name': 'Агапитов',
#   'email': None,
#   'score': 22.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'n0tmyself',
#   'first_name': 'Дмитрий Владимирович',
#   'last_name': 'Альшевский',
#   'email': None,
#   'score': 25.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Kraagger-del',
#   'first_name': 'Семён Дмитриевич',
#   'last_name': 'Балицкий',
#   'email': None,
#   'score': 4.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'nbelyaev1',
#   'first_name': 'Никита Игоревич',
#   'last_name': 'Беляев',
#   'email': None,
#   'score': 15.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'nbusko',
#   'first_name': 'Никита Алексеевич',
#   'last_name': 'Бусько',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'alexbuyan',
#   'first_name': 'Александр Алексеевич',
#   'last_name': 'Буянтуев',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'ONEPANTSU',
#   'first_name': 'Иван Артемьевич',
#   'last_name': 'Внуков',
#   'email': None,
#   'score': 0.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': '7Askar7',
#   'first_name': 'Аскар Тимурович',
#   'last_name': 'Галяутдинов',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'nsgorbunov',
#   'first_name': 'Никита Сергеевич',
#   'last_name': 'Горбунов',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'semyondipner',
#   'first_name': 'Семен Павлович',
#   'last_name': 'Дипнер',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'UsefulTornado',
#   'first_name': 'Артём Александрович',
#   'last_name': 'Иванов',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'anaaaiva',
#   'first_name': 'Анастасия Алексеевна',
#   'last_name': 'Иванова',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'ArtemIgnatenko',
#   'first_name': 'Артем Викторович',
#   'last_name': 'Игнатенко',
#   'email': None,
#   'score': 24.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'GlebIsrailevich',
#   'first_name': 'Глеб Романович',
#   'last_name': 'Ильин',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'katimanova',
#   'first_name': 'Анастасия Тарасовна',
#   'last_name': 'Калиманова',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'EugenePWN',
#   'first_name': 'Евгений Алексеевич',
#   'last_name': 'Капустин',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'AlViKl',
#   'first_name': 'Александр Викторович',
#   'last_name': 'Клакевич',
#   'email': None,
#   'score': 12.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'pavelkochkin1',
#   'first_name': 'Павел Васильевич',
#   'last_name': 'Кочкин',
#   'email': None,
#   'score': 26.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Mihail-Olegovich',
#   'first_name': 'Михаил Олегович',
#   'last_name': 'Куляскин',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'BulatMaratovich',
#   'first_name': 'Булат Маратович',
#   'last_name': 'Латыпов',
#   'email': None,
#   'score': 16.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'limmark21',
#   'first_name': 'Марк Вячеславович',
#   'last_name': 'Лим',
#   'email': None,
#   'score': 0.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Qeshtir',
#   'first_name': 'Игорь Юрьевич',
#   'last_name': 'Макаров',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': '1MaxOn1',
#   'first_name': 'Максим Александрович',
#   'last_name': 'Малаховский',
#   'email': None,
#   'score': 5.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'martynov-dm',
#   'first_name': 'Дмитрий Александрович',
#   'last_name': 'Мартынов',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'FanisNgv',
#   'first_name': 'Фанис Магефурович',
#   'last_name': 'Нигамадянов',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'ShamilNur',
#   'first_name': 'Шамиль Фиданович',
#   'last_name': 'Нуркаев',
#   'email': None,
#   'score': 26.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'nikiduki',
#   'first_name': 'Никита Александрович',
#   'last_name': 'Облаков',
#   'email': None,
#   'score': 8.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'qw1zzard',
#   'first_name': 'Игорь Алексеевич',
#   'last_name': 'Пивнев',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'LeftGoga',
#   'first_name': 'Егор Сергеевич',
#   'last_name': 'Поляков',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'popov101',
#   'first_name': 'Владимир Алексеевич',
#   'last_name': 'Попов',
#   'email': None,
#   'score': 18.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'DmitryRedko',
#   'first_name': 'Дмитрий Александрович',
#   'last_name': 'Редько',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Darinochka',
#   'first_name': 'Дарина Дмитриевна',
#   'last_name': 'Рустамова',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'PaulRychkov',
#   'first_name': 'Павел Андреевич',
#   'last_name': 'Рычков',
#   'email': None,
#   'score': 25.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'savoskinsemyonq',
#   'first_name': 'Семён Витальевич',
#   'last_name': 'Савоськин',
#   'email': None,
#   'score': 24.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Laitielly',
#   'first_name': 'Анна Павловна',
#   'last_name': 'Сидорова',
#   'email': None,
#   'score': 25.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'smalda',
#   'first_name': 'Денис Алексеевич',
#   'last_name': 'Смаль',
#   'email': None,
#   'score': 27.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'NuatStanskiy',
#   'first_name': 'Илья Сергеевич',
#   'last_name': 'Смирнов',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'timsmr',
#   'first_name': 'Тимур Олегович',
#   'last_name': 'Смирнов',
#   'email': None,
#   'score': 27.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'stasstaf',
#   'first_name': 'Станислав Александрович',
#   'last_name': 'Стафиевский',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'ElenaSuhova',
#   'first_name': 'Елена Михайловна',
#   'last_name': 'Сухова',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Postironia1',
#   'first_name': 'Владислав Дмитриевич',
#   'last_name': 'Тимофеев',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'dimajyg',
#   'first_name': 'Дмитрий Александрович',
#   'last_name': 'Тихановский',
#   'email': None,
#   'score': 30.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'nonodoubt',
#   'first_name': 'Евгений Сергеевич',
#   'last_name': 'Фомин',
#   'email': None,
#   'score': 26.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'khrstln',
#   'first_name': 'Илия Дмитриевич',
#   'last_name': 'Хрусталев',
#   'email': None,
#   'score': 21.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'Evgenii-Iurin',
#   'first_name': 'Евгений Станиславович',
#   'last_name': 'Юрин',
#   'email': None,
#   'score': 23.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'wilfordaf',
#   'first_name': 'Сергей Николаевич',
#   'last_name': 'Юрпалов',
#   'email': None,
#   'score': 26.0,
#   'max_score': 30.0,
#   'lms_user_id': None},
#  {'id': 'V-slav-github',
#   'first_name': 'Владислав Леонидович',
#   'last_name': 'Яковлев',
#   'email': None,
#   'score': 28.0,
#   'max_score': 30.0,
#   'lms_user_id': None}]

# %% [markdown]
# # Collect

# %%
nbg.collect(ASSIGNMENT, update=False)
# Out:
# {'success': True,
#  'log': "[INFO] Processing 41 submissions of 'hw_3' for course 'itmo_recsys_2025_spring'\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/smalda+hw_3+2025-04-03T05:42:09 UTC+00 claims to be submitted by smalda but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: smalda hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/ElenaSuhova+hw_3+2025-04-03T05:42:43 UTC+00 claims to be submitted by ElenaSuhova but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: ElenaSuhova hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/qw1zzard+hw_3+2025-04-03T05:42:19 UTC+00 claims to be submitted by qw1zzard but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: qw1zzard hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/7Askar7+hw_3+2025-04-03T05:42:46 UTC+00 claims to be submitted by 7Askar7 but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: 7Askar7 hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/LeftGoga+hw_3+2025-04-03T05:42:57 UTC+00 claims to be submitted by LeftGoga but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Updating submission: LeftGoga hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/Mihail-Olegovich+hw_3+2025-04-03T05:42:54 UTC+00 claims to be submitted by Mihail-Olegovich but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Updating submission: Mihail-Olegovich hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/GlebIsrailevich+hw_3+2025-04-03T05:41:59 UTC+00 claims to be submitted by GlebIsrailevich but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: GlebIsrailevich hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/Qeshtir+hw_3+2025-04-03T05:42:29 UTC+00 claims to be submitted by Qeshtir but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: Qeshtir hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/PaulRychkov+hw_3+2025-04-03T05:42:58 UTC+00 claims to be submitted by PaulRychkov but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: PaulRychkov hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/Postironia1+hw_3+2025-04-03T05:42:35 UTC+00 claims to be submitted by Postironia1 but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: Postironia1 hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/n0tmyself+hw_3+2025-04-03T05:42:48 UTC+00 claims to be submitted by n0tmyself but is owned by dev; cheating attempt?\n    you may disable this warning by unsetting the option CollectApp.check_owner\n    \n[INFO] Collecting submission: n0tmyself hw_3\n[WARNING] \n    /usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/inbound/EugenePWN+hw_3+2025-04-03T05:42:52 UTC+00 claims to be submitted by EugenePWN but is owned by dev; cheating attempt?\n    you m ...

# %% [markdown]
# # Autograde

# %%
autograded_student_ids = nbg.get_autograded_students(ASSIGNMENT)
scores = {
    s_id: gradebook.find_submission_notebook(NOTEBOOK, ASSIGNMENT, s_id).score
    for s_id in autograded_student_ids
}
len({s_id: score for s_id, score in scores.items() if score < MAX_SCORE})
# Out:
# 6

# %%
for student_id, score in scores.items():
    if score == MAX_SCORE:
        continue
    print(f"{student_id}: {score}")
    
    nb_path = Path("autograded") / student_id / ASSIGNMENT / f"{NOTEBOOK}.ipynb"
    nb_text = nb_path.read_text()

    if "CellTimeoutError" in nb_text:
        print("- CellTimeoutError")
        
        
    elif "ModuleNotFound" in nb_text:
        print("  - Module not found")
        for match in re.findall(r"ModuleNotFound.+", nb_text):
            print(f"    - {match}")

    elif "NameError" in nb_text:
        print("  - NameError")
        for match in re.findall(r"NameError.+not defined", nb_text):
            print(f"    - {match}")

    print("=" * 50)
    print()
# Out:
# martynov-dm: 12.0
# ==================================================
#
# popov101: 10.0
# ==================================================
#
# BulatMaratovich: 7.0
#   - NameError
#     - NameError\u001b: name 'interactions' is not defined
#     - NameError\u001b: name 'd' is not defined
#     - NameError\u001b: name 'reco_hot' is not defined
#     - NameError\u001b: name 'reco_hot' is not defined
#     - NameError\u001b: name 'd' is not defined
#     - NameError\u001b: name 'd' is not defined
# ==================================================
#
# Qeshtir: 13.0
# ==================================================
#
# smalda: 12.0
# ==================================================
#
# nonodoubt: 12.0
# ==================================================

# %% [raw]
# BulatMaratovich - 'd' is not defined - косяк в коде
# popov101 - ошибок нет, но последние 5 баллов не начислились почему-то (может ворнинги??)
# Qeshtir - ошибок нет, но 2 балла не начислились почему-то (может ворнинги??)
# martynov-dm - не сошлось число юзеров, причем в открытом тесте - его косяк видимо
# smalda - не сошлось число юзеров, причем в открытом тесте - его косяк видимо
# nonodoubt - не сошлось число юзеров, причем в открытом тесте - его косяк видимо
# ONEPANTSU - не проскорился

# %%
student_ids_requested_to_grade = [
    "nonodoubt",  # timeout
    "stasstaf",  # timeout
    "V-slav-github",  # timeout
]
# student_ids_requested_to_grade = None

# %% [raw]
# autograded_student_ids = nbg.get_autograded_students(ASSIGNMENT)
# zero_scored_user_ids = []
# for student_id in autograded_student_ids:
#     nb = gradebook.find_submission_notebook(NOTEBOOK, ASSIGNMENT, student_id)
#     if nb.score == 0:
#         zero_scored_user_ids.append(student_id)
# student_ids_requested_to_grade = zero_scored_user_ids
# len(student_ids_requested_to_grade)

# %%
submitted_student_ids = nbg.get_submitted_students(ASSIGNMENT)
type(submitted_student_ids), len(submitted_student_ids)
# Out:
# (set, 41)

# %%
autograded_student_ids = nbg.get_autograded_students(ASSIGNMENT)
type(autograded_student_ids), len(autograded_student_ids)
# Out:
# (set, 40)

# %%
not_autograded_student_ids = list(submitted_student_ids - autograded_student_ids)
len(not_autograded_student_ids)
# Out:
# 1

# %%
if student_ids_requested_to_grade is not None:
    student_ids_to_grade = student_ids_requested_to_grade
    force = True
else:
    student_ids_to_grade = not_autograded_student_ids
    force = False

# %%
f"{force=}", student_ids_to_grade
# Out:
# ('force=True', ['nonodoubt', 'stasstaf', 'V-slav-github'])

# %%
results = {}
for student_id in tqdm(student_ids_to_grade):
    ts = time.time()
    res = nbg.autograde(assignment_id=ASSIGNMENT, student_id=student_id, force=force, create=False)
    elapsed = time.time() - ts
    res["time"] = elapsed
    results[student_id] = res
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# successes = [res for res in results if res["success"]]
# failures = [res for res in results if not res["success"]]

# graded = [res for res in successes if "[INFO] Autograding" in res["log"]]
# skipped = [res for res in successes if res["log"].startswith("[INFO] Skipping")]


# print("Total: ", len(results))
# print("failures: ", len(failures))
# print("successes: ", len(successes))
# print("graded: ", len(graded))
# print("skipped: ", len(skipped))

# %% [raw]
# i = 0
# print(failures[i]["log"])
# print()
# print(failures[i]["error"])

# %% [markdown]
# # Get per-task scores

# %%
student_ids_requested_to_grade = None

# %%
if student_ids_requested_to_grade is not None:
    students_to_get_scores = student_ids_requested_to_grade
else:
    students_to_get_scores = nbg.get_autograded_students(ASSIGNMENT)

# %%
scores = {}
for student_id in tqdm(students_to_get_scores):
    nb = gradebook.find_submission_notebook(NOTEBOOK, ASSIGNMENT, student_id)
    student_scores = {
        "total": {"actual": nb.score, "max": nb.max_score},
        "cells": [
            {"actual": g.score, "max": g.max_score}
            for g in nb.grades
        ]
    }
    scores[student_id] = student_scores
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
scores
# Out:
# {'dimajyg': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'DmitryRedko': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'PaulRychkov': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'n0tmyself': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'LeftGoga': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'Postironia1': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'khrstln': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'V-slav-github': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'nbusko': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'GlebIsrailevich': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'ShamilNur': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'FanisNgv': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'martynov-dm': {'total': {'actual': 12.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 0.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'Laitielly': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'UsefulTornado': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'wilfordaf': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'koshkidadanet': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'savoskinsemyonq': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'popov101': {'total': {'actual': 10.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 0.0, 'max': 5.0}]},
#  'stasstaf': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'EugenePWN': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'BulatMaratovich': {'total': {'actual': 7.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 0.0, 'max': 3.0},
#    {'actual': 0.0, 'max': 5.0}]},
#  'Qeshtir': {'total': {'actual': 13.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 0.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'smalda': {'total': {'actual': 12.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 0.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'semyondipner': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'anaaaiva': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'alexbuyan': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'Evgenii-Iurin': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'timsmr': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'Mihail-Olegovich': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'qw1zzard': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'katimanova': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'nsgorbunov': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  '7Askar7': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'ArtemIgnatenko': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'NuatStanskiy': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'Darinochka': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'ElenaSuhova': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'pavelkochkin1': {'total': {'actual': 15.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 3.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]},
#  'nonodoubt': {'total': {'actual': 12.0, 'max': 15.0},
#   'cells': [{'actual': 3.0, 'max': 3.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 2.0, 'max': 2.0},
#    {'actual': 0.0, 'max': 3.0},
#    {'actual': 5.0, 'max': 5.0}]}}

# %% [markdown]
# # Make human-readable feedback

# %%
CELL_NAMES = [
    "тестовая выборка",  
    "правильность холодных", 
    "метрики холодных", 
    "правильность горячих", 
    "метрики горячих",
]

# %% [markdown]
# **Скоры предполагаются целыми**

# %%
feedbacks = []
for student_id, student_scores in scores.items():
    total_score = student_scores["total"]
    feedback_scores = [f"total: {total_score['actual']:.0f} / {total_score['max']:.0f}"]
    for cell_name, cell_score in zip(CELL_NAMES, student_scores["cells"]):
        feedback_scores.append(f"{cell_name}: {cell_score['actual']:.0f} / {cell_score['max']:.0f}")
    feedback = {
        "student_id": student_id,
        "feedback": ", ".join(feedback_scores),
        "score": round(total_score["actual"])
    }
    feedbacks.append(feedback)

# %%
feedbacks
# Out:
# [{'student_id': 'dimajyg',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'DmitryRedko',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'PaulRychkov',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'n0tmyself',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'LeftGoga',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'Postironia1',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'khrstln',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'V-slav-github',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'nbusko',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'GlebIsrailevich',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'ShamilNur',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'FanisNgv',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'martynov-dm',
#   'feedback': 'total: 12 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 0 / 3, метрики горячих: 5 / 5',
#   'score': 12},
#  {'student_id': 'Laitielly',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'UsefulTornado',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'wilfordaf',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'koshkidadanet',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'savoskinsemyonq',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'popov101',
#   'feedback': 'total: 10 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 0 / 5',
#   'score': 10},
#  {'student_id': 'stasstaf',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'EugenePWN',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'BulatMaratovich',
#   'feedback': 'total: 7 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 0 / 3, метрики горячих: 0 / 5',
#   'score': 7},
#  {'student_id': 'Qeshtir',
#   'feedback': 'total: 13 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 0 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 13},
#  {'student_id': 'smalda',
#   'feedback': 'total: 12 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 0 / 3, метрики горячих: 5 / 5',
#   'score': 12},
#  {'student_id': 'semyondipner',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'anaaaiva',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'alexbuyan',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'Evgenii-Iurin',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'timsmr',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'Mihail-Olegovich',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'qw1zzard',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'katimanova',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'nsgorbunov',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': '7Askar7',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'ArtemIgnatenko',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'NuatStanskiy',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'Darinochka',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'ElenaSuhova',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'pavelkochkin1',
#   'feedback': 'total: 15 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 3 / 3, метрики горячих: 5 / 5',
#   'score': 15},
#  {'student_id': 'nonodoubt',
#   'feedback': 'total: 12 / 15, тестовая выборка: 3 / 3, правильность холодных: 2 / 2, метрики холодных: 2 / 2, правильность горячих: 0 / 3, метрики горячих: 5 / 5',
#   'score': 12}]

# %%
df = pd.DataFrame(feedbacks)
df
# Out:
#           student_id                                           feedback  score
# 0            dimajyg  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 1        DmitryRedko  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 2        PaulRychkov  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 3          n0tmyself  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 4           LeftGoga  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 5        Postironia1  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 6            khrstln  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 7      V-slav-github  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 8             nbusko  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 9    GlebIsrailevich  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 10         ShamilNur  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 11          FanisNgv  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 12       martynov-dm  total: 12 / 15, тестовая выборка: 3 / 3, прави...     12
# 13         Laitielly  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 14     UsefulTornado  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 15         wilfordaf  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 16     koshkidadanet  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 17   savoskinsemyonq  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 18          popov101  total: 10 / 15, тестовая выборка: 3 / 3, прави...     10
# 19          stasstaf  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 20         EugenePWN  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 21   BulatMaratovich  total: 7 / 15, тестовая выборка: 3 / 3, правил...      7
# 22           Qeshtir  total: 13 / 15, тестовая выборка: 3 / 3, прави...     13
# 23            smalda  total: 12 / 15, тестовая выборка: 3 / 3, прави...     12
# 24      semyondipner  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 25          anaaaiva  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 26         alexbuyan  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 27     Evgenii-Iurin  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 28            timsmr  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 29  Mihail-Olegovich  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 30          qw1zzard  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 31        katimanova  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 32        nsgorbunov  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 33           7Askar7  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 34    ArtemIgnatenko  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 35      NuatStanskiy  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 36        Darinochka  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 37       ElenaSuhova  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 38     pavelkochkin1  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 39         nonodoubt  total: 12 / 15, тестовая выборка: 3 / 3, прави...     12

# %%
df["feedback"][0]
# Out:
# 'total: 9 / 15, precision_and_recall: 1 / 1, ap_at_3_for_user_2: 1 / 1, map_at_3: 1 / 1, dcg_at_3_for_user_2: 1 / 1, idcg_at_3_for_user_2: 1 / 1, ndcg_at_3: 0 / 1, weighted_recall_correct: 0 / 2, weighted_recall_efficient: 0 / 3, model_A: 2 / 2, model_B: 2 / 2'

# %%
students_df = pd.read_csv("/usr/local/share/nbgrader/exchange/itmo_recsys_2025_spring/students.tsv", sep="\t")

students_df = students_df.loc[students_df["Github repo"].notnull()].copy()
students_df["student_id"] = students_df["Github repo"].str.removeprefix("https://github.com/").str.split("/", expand=True)[0]
students_df = students_df[["ФИО", "student_id"]]
students_df.head()
# Out:
#                              ФИО       student_id
# 1      Горбунов Никита Сергеевич       nsgorbunov
# 2           Ильин Глеб Романович  GlebIsrailevich
# 3  Клакевич Александр Викторович           AlViKl
# 4        Латыпов Булат Маратович  BulatMaratovich
# 6      Попов Владимир Алексеевич         popov101

# %%
student_id_to_name = students_df.set_index("student_id")["ФИО"]
df.insert(0, "ФИО", df["student_id"].map(student_id_to_name))
df.head()
# Out:
#                                  ФИО   student_id  \
# 0  Тихановский Дмитрий Александрович      dimajyg
# 1       Редько Дмитрий Александрович  DmitryRedko
# 2             Рычков Павел Андреевич  PaulRychkov
# 3    Альшевский Дмитрий Владимирович    n0tmyself
# 4             Поляков Егор Сергеевич     LeftGoga
#
#                                             feedback  score
# 0  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 1  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 2  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 3  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15
# 4  total: 15 / 15, тестовая выборка: 3 / 3, прави...     15

# %%
df.to_csv("hw_3_feedback.tsv", sep="\t", index=False)
